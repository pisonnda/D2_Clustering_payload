# %% [markdown]
# <h2> Draw a graph from result </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def draw_csv(file_path):
    columns_name = ['Date', 'Uniq Payload', 'New Payload']
    df = pd.read_csv(file_path, sep='\t', engine='python', index_col=0, header=None, names=columns_name)
    df.plot(kind="line")
# Out:
#           Uniq Payload  New Payload
# Date
# 20170901         21024        21024
# 20170902         25500        24957
# 20170903         20873        20071
# 20170904         19560        18636
# 20170905         22842        21577

# %%
df.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# !ls csv
# Out:
# as42470_srcip  pay_63199  query.sql  srcip_63199
# pay_42570      query.py   shinki.py

# %% [markdown]
# <h2>Make data base from darknet</h2>

# %%
import mysql.connector
from mysql.connector import Error 
import pandas as pd

# %%
def create_server_connection(host_name, user_name, user_password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# %%
pw = 'Ramen!yokosuka2023'
connection = create_server_connection("localhost", "pison", pw)
# Out:
# MySQL Database connection successful

# %%
def create_database(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        print("Database created successfully")
    except Error as err:
        print(f"Error: '{err}'")

# %%
create_database_query = "CREATE DATABASE dark_test"
create_database(connection, create_database_query)
# Out:
# Error: '1007 (HY000): Can't create database 'dark_test'; database exists'

# %%
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password,
            database=db_name
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query successful")
    except Error as err:
        print(f"Error: '{err}'")

# %%
db = "dark_test"
create_dark_test_table = """
CREATE TABLE information (
    dstip_id INT PRIMARY KEY,
    srcip INT,
    time FLOAT
    );
"""
connection = create_db_connection("localhost", "pison", pw, db)
execute_query(connection, create_dark_test_table)
# Out:
# MySQL Database connection successful
# Query successful

# %%
pop_data = """
INSERT INTO information VALUES
(8888, 1111, 22.22),
(9999, 3333, 55.55)
"""
connection = create_db_connection('localhost', 'pison', pw, db)
execute_query(connection, pop_data)
# Out:
# MySQL Database connection successful
# Query successful

# %%
data = [
    ([6666], 2, 3.0),
    ([1234], 2, 3.0)
]
test_query = '''
INSERT INTO information (dstip_id, srcip, time) VALUES (%s, %s, %s)
'''
connection = create_db_connection('localhost', 'pison', pw, 'dark_test')
cursor = connection.cursor()
cursor.executemany(test_query, data)
connection.commit()
cursor.close()
# Out:
# MySQL Database connection successful
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#       8 connection = create_db_connection('localhost', 'pison', pw, 'dark_test')
#       9 cursor = connection.cursor()
# ---> 10 cursor.executemany(test_query, data)
#      11 connection.commit()
#      12 cursor.close()
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor_cext.py:375, in CMySQLCursor.executemany(self, operation, seq_params)
#     373 try:
#     374     for params in seq_params:
# --> 375         self.execute(operation, params)
#     376         try:
#     377             while True:
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor_cext.py:263, in CMySQLCursor.execute(self, operation, params, multi)
#     260     raise ProgrammingError(str(err)) from err
#     262 if params:
# --> 263     prepared = self._cnx.prepare_for_mysql(params)
#     264     if isinstance(prepared, dict):
#     265         for key, value in prepared.items():
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/connection_cext.py:716, in CMySQLConnection.prepare_for_mysql(self, params)
#     709         result = [
#     710             self.converter.quote(
#     711                 self.converter.escape(self.converter.to_mysql(value))
#     712             )
#     713             for value in params
#     714         ]
#     715     else:
# --> 716         result = self._cmysql.convert_to_mysql(*params)
#     717 elif isinstance(params, dict):
#     718     result = {}
#
# MySQLInterfaceError: Python type list cannot be converted

# %% [markdown]
# 参考サイト：
# 1. PythonでMySQLデータベース作成：https://www.freecodecamp.org/japanese/news/connect-python-with-sql/
#
# 2. リストからMySQLデータベースへ挿入（INSERT):
# https://python.softmoco.com/basics/python-mysql-insert.php
